# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("./Crop_recommendation.csv")
dataset.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
modified_dataset=dataset

# %%
modified_dataset.label=le.fit_transform(modified_dataset.label)
modified_dataset
# Out:
#         N   P   K  temperature   humidity        ph    rainfall  label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536     20
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537     20
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248     20
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034     20
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340     20
# ...   ...  ..  ..          ...        ...       ...         ...    ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507      5
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610      5
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839      5
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293      5
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041      5
#
# [2200 rows x 8 columns]

# %%
modified_dataset=modified_dataset.sample(frac=1).reset_index(drop=True)
modified_dataset.to_csv("Modfied_Dataset.csv",index=False)
modified_dataset
# Out:
#         N    P    K  temperature   humidity        ph    rainfall  label
# 0      27   56   20    19.259754  20.513470  5.542690   94.953353      9
# 1      26   65   22    17.848066  18.776220  5.949949  143.098417      9
# 2      71   46   40    20.280194  82.123542  7.236705  191.953574     20
# 3     111   32   34    25.467437  69.351612  6.392048  171.376446      5
# 4      22  144  196    21.911913  91.687481  6.499227  117.076128      0
# ...   ...  ...  ...          ...        ...       ...         ...    ...
# 2195  119   90   48    28.667251  79.592425  5.986442  118.258344      1
# 2196   30   65   25    32.887338  64.594574  7.706509   71.505695      2
# 2197   33   59   19    23.193053  62.747108  7.641024   49.552133     10
# 2198    3   67   24    17.000676  19.907905  5.520880  103.292641      9
# 2199    8   23   44    18.474124  89.689197  7.130838  108.475851     19
#
# [2200 rows x 8 columns]

# %%
np.random.seed(42)

data = modified_dataset.drop('label',axis=1)
target = modified_dataset['label']

# %%
data.head()
# Out:
#      N    P    K  temperature   humidity        ph    rainfall
# 0   27   56   20    19.259754  20.513470  5.542690   94.953353
# 1   26   65   22    17.848066  18.776220  5.949949  143.098417
# 2   71   46   40    20.280194  82.123542  7.236705  191.953574
# 3  111   32   34    25.467437  69.351612  6.392048  171.376446
# 4   22  144  196    21.911913  91.687481  6.499227  117.076128

# %%
target.head()
# Out:
# 0     9
# 1     9
# 2    20
# 3     5
# 4     0
# Name: label, dtype: int64

# %%
from sklearn.model_selection import train_test_split
data_train, data_test, target_train, target_test = train_test_split(data, target, test_size=0.3)

# %%
from sklearn.ensemble import

# %%
clf=RandomForestClassifier()

clf.fit(data_train, target_train)
clf.score(data_test, target_test)
# Out:
# 0.9939393939393939

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
y_preds_test = clf.predict(data_test)
accuracy_score(target_test, y_preds_test)
# Out:
# 0.9939393939393939

# %%
matrix = confusion_matrix(target_test, y_preds_test)

import seaborn as sns

# %%
plt.figure(figsize=(16,7))
sns.set(font_scale=1.4)
sns.heatmap(matrix, annot=True, cmap=plt.cm.Greens, annot_kws={'size':10}, linewidths=0.2)
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix for Random Forest Model')
plt.show()

# %%
import pickle
pickle.dump(clf,open('crop_recommendation_model.pkl','wb'))
